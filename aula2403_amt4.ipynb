# %% [markdown]
# <a href="https://colab.research.google.com/github/IsabelaNeves1/am-t4-s1a2026/blob/main/aula2403_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução de Python

# %%
a=2
b=3
print('A soma é: ',a+b)
# Out:
# A soma é:  5

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print('A multiplicação é: ',c*d)
# Out:
# A multiplicação é:  20

# %% [markdown]
# #Biblioteca e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Numero sem raiz', delta

  x1 = (-b + math.sqrt(delta)) /(2*a)
  x2 = (-b - math.sqrt(delta)) /(2*a)

  return x1, x2

# %% [markdown]
# ##Testes de Função Matemática

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)
  eq += equacao2grau(a, b, c)

# %%
for i in range(12):
  if(i % 2 == 0):
    if (eq[i] != 'Numero sem raiz'):
      print('X1: [', f"{eq[i]:.2f}",']')
  else:
    if (eq[i] != 'Numero sem raiz'):
      print('X2: [', f"{eq[i]:.2f}",']\n')
# Out:
# X1: [ 2.00 ]
# X2: [ 1.00 ]
#
# X1: [ 4.07 ]
# X2: [ -0.74 ]
#
# X1: [ -0.42 ]
# X2: [ -1.58 ]
#
# X1: [ -2.41 ]
# X2: [ 0.41 ]
#
# X2: [ -40.00 ]
#
# X2: [ -91.00 ]
